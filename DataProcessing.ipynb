# %%
import os
os.chdir("C:\\Users\\khali\\OneDrive\\Área de Trabalho\\LSTM-FCN-master")

import librosa as lr
import pandas as pd
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import random
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
data = glob('_data/all_data' + '/*.wav')
#random.shuffle(data)

label = []
for d in data:
    if 'H' in d:
        label.append('0')
    elif 'S' in d:
        label.append('1')
    elif 'happy' in d:
        label.append('0')
    elif 'angry' in d:
        label.append('1')

# %%
labels = pd.DataFrame(label)
labels.columns = [-1]

features_data = pd.DataFrame(columns=['feature'])
bookmark=0

# %%
new_feature = []
for file,y in enumerate(data):
    X,sample_rate = lr.load(data[file],res_type='kaiser_fast',duration=3,sr=8000*2,offset=0)
    print('file '+str(bookmark))
    sample_rate = np.array(sample_rate)
    mfccs = lr.feature.mfcc(y=X,sr=sample_rate,n_mfcc=15)
    new_feature.append(np.mean(mfccs[0]))
    new_feature.append(np.mean(mfccs[1]))
    new_feature.append(np.mean(mfccs[2]))
    new_feature.append(np.mean(mfccs[3]))
    new_feature.append(np.mean(mfccs[4]))
    new_feature.append(np.mean(mfccs[5]))
    new_feature.append(np.mean(mfccs[6]))
    new_feature.append(np.mean(mfccs[7]))
    new_feature.append(np.mean(mfccs[8]))
    new_feature.append(np.mean(mfccs[9]))
    new_feature.append(np.mean(mfccs[10]))
    new_feature.append(np.mean(mfccs[11]))
    new_feature.append(np.mean(mfccs[12]))
    new_feature.append(np.mean(mfccs[13]))
    new_feature.append(np.mean(mfccs[14]))
    
    features_data.loc[bookmark] = [new_feature]
    
    new_feature = []
    bookmark=bookmark+1
# Out:
# file 0
# file 1
# file 2
# file 3
# file 4
# file 5
# file 6
# file 7
# file 8
# file 9
# file 10
# file 11
# file 12
# file 13
# file 14
# file 15
# file 16
# file 17
# file 18
# file 19
# file 20
# file 21
# file 22
# file 23
# file 24
# file 25
# file 26
# file 27
# file 28
# file 29
# file 30
# file 31
# file 32
# file 33
# file 34
# file 35
# file 36
# file 37
# file 38
# file 39
# file 40
# file 41
# file 42
# file 43
# file 44
# file 45
# file 46
# file 47
# file 48
# file 49
# file 50
# file 51
# file 52
# file 53
# file 54
# file 55
# file 56
# file 57
# file 58
# file 59
# file 60
# file 61
# file 62
# file 63
# file 64
# file 65
# file 66
# file 67
# file 68
# file 69
# file 70
# file 71
# file 72
# file 73
# file 74
# file 75
# file 76
# file 77
# file 78
# file 79
# file 80
# file 81
# file 82
# file 83
# file 84
# file 85
# file 86
# file 87
# file 88
# file 89
# file 90
# file 91
# file 92
# file 93
# file 94
# file 95
# file 96
# file 97
# file 98
# file 99
# ...

# %%
df3 = pd.DataFrame(features_data['feature'].values.tolist())

# %%
df3.head()
# Out:
#            0           1          2          3          4          5   \
# 0 -393.872364  143.065715  28.254148  21.915662  36.550758  10.473217
# 1 -372.423796  152.454533  25.547740  23.805177  36.407758   7.179566
# 2 -419.614457  164.926290  16.018537  26.357706  44.721712   2.263494
# 3 -384.084138  144.051446  11.477809   5.889607  28.624909   7.281152
# 4 -382.869809  147.717027  21.790911  16.748959  33.203546   8.217283
#
#          6          7         8         9          10         11        12  \
# 0 -0.911331   8.257899  5.220637  4.708601  10.514065   6.504892  6.667071
# 1  6.794110  19.865749  6.870373  5.237482  14.707940   5.286964  3.571662
# 2  3.128924  26.556902  7.887081 -0.748485  13.830055   7.892138  4.597889
# 3  6.219459  20.318993  6.130387  2.106977  19.824999  14.229084 -0.724291
# 4  9.298968  23.418428  3.936794 -3.981437  15.313313  13.787561  0.820552
#
#           13         14        15         16
# 0  14.438592  11.190200  5.707958   7.592035
# ...

# %%
newdf = pd.concat([df3,labels], axis=1)
final_data = newdf.rename(index=str, columns={"0": "label"})

# %%
final_data

# %%
final_data.fillna(0, inplace=True)

# %%
final_data.head()
# Out:
#            0           1          2          3          4          5   \
# 0 -393.872364  143.065715  28.254148  21.915662  36.550758  10.473217
# 1 -372.423796  152.454533  25.547740  23.805177  36.407758   7.179566
# 2 -419.614457  164.926290  16.018537  26.357706  44.721712   2.263494
# 3 -384.084138  144.051446  11.477809   5.889607  28.624909   7.281152
# 4 -382.869809  147.717027  21.790911  16.748959  33.203546   8.217283
#
#          6          7         8         9          10         11        12  \
# 0 -0.911331   8.257899  5.220637  4.708601  10.514065   6.504892  6.667071
# 1  6.794110  19.865749  6.870373  5.237482  14.707940   5.286964  3.571662
# 2  3.128924  26.556902  7.887081 -0.748485  13.830055   7.892138  4.597889
# 3  6.219459  20.318993  6.130387  2.106977  19.824999  14.229084 -0.724291
# 4  9.298968  23.418428  3.936794 -3.981437  15.313313  13.787561  0.820552
#
#           13         14        15         16 -1
# ...

# %%
final_data.to_csv(r'C:\\Users\\khali\\final_data_15.csv')
